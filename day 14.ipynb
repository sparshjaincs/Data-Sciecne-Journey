# %%
import pandas as pd

# %%
df1=pd.read_csv('titanic_test.csv')
df1
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
df=pd.read_csv('titanic_train.csv',index_col=0)
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %%
df.groupby(['Sex','Pclass'])['Age'].mean()
# Out:
# Sex     Pclass
# female  1         34.611765
#         2         28.722973
#         3         21.750000
# male    1         41.281386
#         2         30.740707
#         3         26.507589
# Name: Age, dtype: float64

# %% [markdown]
# ## Missing Values identification

# %%
df.isnull().sum()  #isna()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
100*df.isnull().sum()/len(df)
# Out:
# Survived     0.000000
# Pclass       0.000000
# Name         0.000000
# Sex          0.000000
# Age         19.865320
# SibSp        0.000000
# Parch        0.000000
# Ticket       0.000000
# Fare         0.000000
# Cabin       77.104377
# Embarked     0.224467
# dtype: float64

# %% [markdown]
# ## Missing Value Treatment

# %%
del df['Cabin']
# df.drop('Cabin',axis=1) # axis=1 means column, axis=0 means row # return something
# df.drop('Cabin',axis=1, inplace= True) # inplace True means self update # dors not return anything

# %%
#df['Age'].fillna(df['Age'].mean())

# dropna() 
# fillna(mean)  #-> preferable
# fillna(0)

# %% [markdown]
# ##### Iterating over data

# %%
for i in df:  # normal technique and gives only names
    print(i)
# Out:
# Survived
# Pclass
# Name
# Sex
# Age
# SibSp
# Parch
# Ticket
# Fare
# Embarked

# %%
for i,c in df.iteritems(): # faster than normal technique and gives tuple result
    print(i)
    print(c)
# Out:
# Survived
# PassengerId
# 1      0
# 2      1
# 3      1
# 4      1
# 5      0
# 6      0
# 7      0
# 8      0
# 9      1
# 10     1
# 11     1
# 12     1
# 13     0
# 14     0
# 15     0
# 16     1
# 17     0
# 18     1
# 19     0
# 20     1
# 21     0
# 22     1
# 23     1
# 24     1
# 25     0
# 26     1
# 27     0
# 28     0
# 29     1
# 30     0
#       ..
# 862    0
# 863    1
# 864    0
# 865    0
# 866    1
# 867    1
# 868    0
# 869    0
# 870    1
# 871    0
# 872    1
# 873    0
# 874    0
# 875    1
# 876    1
# 877    0
# 878    0
# 879    0
# 880    1
# 881    1
# 882    0
# 883    0
# 884    0
# 885    0
# 886    0
# 887    0
# 888    1
# 889    0
# 890    1
# 891    0
# Name: Survived, Length: 891, dtype: int64
# Pclass
# PassengerId
# 1      3
# 2      1
# 3      3
# 4      1
# 5      3
# 6      3
# 7      1
# 8      3
# 9      3
# 10     2
# 11     3
# 12     1
# 13     3
# 14     3
# 15     3
# 16     2
# 17     3
# 18     2
# 19     3
# 20     3
# 21     2
# ...

# %%
for i in df.iterrows(): 
    print(i)
# Out:
# (1, Survived                          0
# Pclass                            3
# Name        Braund, Mr. Owen Harris
# Sex                            male
# Age                              22
# SibSp                             1
# Parch                             0
# Ticket                    A/5 21171
# Fare                           7.25
# Embarked                          S
# Name: 1, dtype: object)
# (2, Survived                                                    1
# Pclass                                                      1
# Name        Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                    female
# Age                                                        38
# SibSp                                                       1
# Parch                                                       0
# Ticket                                               PC 17599
# Fare                                                  71.2833
# ...

# %%
for i,r in df.iterrows(): 
    print((r['Name'],len(r['Name'])))
# Out:
# ('Braund, Mr. Owen Harris', 23)
# ('Cumings, Mrs. John Bradley (Florence Briggs Thayer)', 51)
# ('Heikkinen, Miss. Laina', 22)
# ('Futrelle, Mrs. Jacques Heath (Lily May Peel)', 44)
# ('Allen, Mr. William Henry', 24)
# ('Moran, Mr. James', 16)
# ('McCarthy, Mr. Timothy J', 23)
# ('Palsson, Master. Gosta Leonard', 30)
# ('Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)', 49)
# ('Nasser, Mrs. Nicholas (Adele Achem)', 35)
# ('Sandstrom, Miss. Marguerite Rut', 31)
# ('Bonnell, Miss. Elizabeth', 24)
# ('Saundercock, Mr. William Henry', 30)
# ('Andersson, Mr. Anders Johan', 27)
# ('Vestrom, Miss. Hulda Amanda Adolfina', 36)
# ('Hewlett, Mrs. (Mary D Kingcome) ', 32)
# ('Rice, Master. Eugene', 20)
# ('Williams, Mr. Charles Eugene', 28)
# ('Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)', 55)
# ('Masselmani, Mrs. Fatima', 23)
# ('Fynney, Mr. Joseph J', 20)
# ('Beesley, Mr. Lawrence', 21)
# ('McGowan, Miss. Anna "Annie"', 27)
# ('Sloper, Mr. William Thompson', 28)
# ...

# %%
for i in df.itertuples(): 
    print(i)
# Out:
# Pandas(Index=1, Survived=0, Pclass=3, Name='Braund, Mr. Owen Harris', Sex='male', Age=22.0, SibSp=1, Parch=0, Ticket='A/5 21171', Fare=7.25, Embarked='S')
# Pandas(Index=2, Survived=1, Pclass=1, Name='Cumings, Mrs. John Bradley (Florence Briggs Thayer)', Sex='female', Age=38.0, SibSp=1, Parch=0, Ticket='PC 17599', Fare=71.2833, Embarked='C')
# Pandas(Index=3, Survived=1, Pclass=3, Name='Heikkinen, Miss. Laina', Sex='female', Age=26.0, SibSp=0, Parch=0, Ticket='STON/O2. 3101282', Fare=7.925, Embarked='S')
# Pandas(Index=4, Survived=1, Pclass=1, Name='Futrelle, Mrs. Jacques Heath (Lily May Peel)', Sex='female', Age=35.0, SibSp=1, Parch=0, Ticket='113803', Fare=53.1, Embarked='S')
# Pandas(Index=5, Survived=0, Pclass=3, Name='Allen, Mr. William Henry', Sex='male', Age=35.0, SibSp=0, Parch=0, Ticket='373450', Fare=8.05, Embarked='S')
# Pandas(Index=6, Survived=0, Pclass=3, Name='Moran, Mr. James', Sex='male', Age=nan, SibSp=0, Parch=0, Ticket='330877', Fare=8.4583, Embarked='Q')
# ...

# %%
for i in df.itertuples():  # in itertuples we can also use tuple functions as it behaves like tuple
    print(i[3])
# Out:
# Braund, Mr. Owen Harris
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)
# Heikkinen, Miss. Laina
# Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Allen, Mr. William Henry
# Moran, Mr. James
# McCarthy, Mr. Timothy J
# Palsson, Master. Gosta Leonard
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# Nasser, Mrs. Nicholas (Adele Achem)
# Sandstrom, Miss. Marguerite Rut
# Bonnell, Miss. Elizabeth
# Saundercock, Mr. William Henry
# Andersson, Mr. Anders Johan
# Vestrom, Miss. Hulda Amanda Adolfina
# Hewlett, Mrs. (Mary D Kingcome)
# Rice, Master. Eugene
# Williams, Mr. Charles Eugene
# Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)
# Masselmani, Mrs. Fatima
# Fynney, Mr. Joseph J
# Beesley, Mr. Lawrence
# McGowan, Miss. Anna "Annie"
# Sloper, Mr. William Thompson
# Palsson, Miss. Torborg Danira
# Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)
# Emir, Mr. Farred Chehab
# Fortune, Mr. Charles Alexander
# O'Dwyer, Miss. Ellen "Nellie"
# Todoroff, Mr. Lalio
# ...

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Embarked'],
#       dtype='object')

# %%
df.apply(lambda x:(x['Name'],len(x['Name'])),axis=1)
# Out:
# PassengerId
# 1                          (Braund, Mr. Owen Harris, 23)
# 2      (Cumings, Mrs. John Bradley (Florence Briggs T...
# 3                           (Heikkinen, Miss. Laina, 22)
# 4      (Futrelle, Mrs. Jacques Heath (Lily May Peel),...
# 5                         (Allen, Mr. William Henry, 24)
# 6                                 (Moran, Mr. James, 16)
# 7                          (McCarthy, Mr. Timothy J, 23)
# 8                   (Palsson, Master. Gosta Leonard, 30)
# 9      (Johnson, Mrs. Oscar W (Elisabeth Vilhelmina B...
# 10             (Nasser, Mrs. Nicholas (Adele Achem), 35)
# 11                 (Sandstrom, Miss. Marguerite Rut, 31)
# 12                        (Bonnell, Miss. Elizabeth, 24)
# 13                  (Saundercock, Mr. William Henry, 30)
# 14                     (Andersson, Mr. Anders Johan, 27)
# 15            (Vestrom, Miss. Hulda Amanda Adolfina, 36)
# 16                (Hewlett, Mrs. (Mary D Kingcome) , 32)
# ...

# %%
df.apply(lambda x:(x['Name'],(x['Sex'])),axis=1)
# Out:
# PassengerId
# 1                        (Braund, Mr. Owen Harris, male)
# 2      (Cumings, Mrs. John Bradley (Florence Briggs T...
# 3                       (Heikkinen, Miss. Laina, female)
# 4      (Futrelle, Mrs. Jacques Heath (Lily May Peel),...
# 5                       (Allen, Mr. William Henry, male)
# 6                               (Moran, Mr. James, male)
# 7                        (McCarthy, Mr. Timothy J, male)
# 8                 (Palsson, Master. Gosta Leonard, male)
# 9      (Johnson, Mrs. Oscar W (Elisabeth Vilhelmina B...
# 10         (Nasser, Mrs. Nicholas (Adele Achem), female)
# 11             (Sandstrom, Miss. Marguerite Rut, female)
# 12                    (Bonnell, Miss. Elizabeth, female)
# 13                (Saundercock, Mr. William Henry, male)
# 14                   (Andersson, Mr. Anders Johan, male)
# 15        (Vestrom, Miss. Hulda Amanda Adolfina, female)
# 16            (Hewlett, Mrs. (Mary D Kingcome) , female)
# ...

# %% [markdown]
# ### program to fill missing values in age column

# %%
def age_treat(x):
    age=x['Age']
    sex=x['Sex']
    pclass=x['Pclass']
    if pd.isnull(age):
        if sex=='male' and pclass ==1:
            return df['Age'][(df['Sex']=='male') & (df['Pclass']==1)].mean()
        elif sex=='male' and pclass ==2:
            return df['Age'][(df['Sex']=='male') & (df['Pclass']==2)].mean()
        elif sex=='male' and pclass ==3:
            return df['Age'][(df['Sex']=='male') & (df['Pclass']==3)].mean()
        elif sex=='female' and pclass ==1:
            return df['Age'][(df['Sex']=='female') & (df['Pclass']==1)].mean()
        elif sex=='female' and pclass ==2:
            return df['Age'][(df['Sex']=='female') & (df['Pclass']==2)].mean()
        elif sex=='female' and pclass ==3:
            return df['Age'][(df['Sex']=='female') & (df['Pclass']==3)].mean()
    return age

# %%
df['Age']=df[['Sex','Pclass','Age']].apply(age_treat,axis=1)

# %%
df.dropna(axis=0,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 1 to 891
# Data columns (total 10 columns):
# Survived    889 non-null int64
# Pclass      889 non-null int64
# Name        889 non-null object
# Sex         889 non-null object
# Age         889 non-null float64
# SibSp       889 non-null int64
# Parch       889 non-null int64
# Ticket      889 non-null object
# Fare        889 non-null float64
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 76.4+ KB

# %%
df.head(5)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500        S
# 2                1      0          PC 17599  71.2833        C
# 3                0      0  STON/O2. 3101282   7.9250        S
# ...

# %% [markdown]
# ## Graphical Visualisation
# 1. MATPLOTLIB
# 2. PANDAS
# 3. SEABORN
# 4. PLOTLY(hum yeh wala nahi kar rahe)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot()
# Out:
# []

# %%
plt.plot()     #draw a line plot
plt.bar()      #vertical lines of datapoints
plt.box()      #quantiles(25%, 50%, 75%),outliers
plt.boxplot()  #quantiles(25%, 50%, 75%),outliers
plt.barh()     #horizontal lines of datapoints
plt.hexbin()   #compares two attributes in a shape of hexagons
plt.hist()     #histogram(connected bars)
plt.scatter()  #simple scatter of two attributes
plt.violinplot()

# %%
plt.plot(df['Age'])

# %%
plt.plot(df['Age'].head(30))

# %%
plt.bar(range(30),df['Age'].head(30))
# Out:
# <BarContainer object of 30 artists>

# %%
p=plt.hist(df['Age'],bins=20)

# %%
plt.barh(range(30),df['Age'].head(30))
# Out:
# <BarContainer object of 30 artists>

# %%
plt.scatter(df['Age'],df['Fare']) # can only compare numerical values , cannot compare string values

# %%
df[['Age','Fare']].corr()
# Out:
#            Age      Fare
# Age   1.000000  0.115477
# Fare  0.115477  1.000000

# %%
df.corr()
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.335549 -0.072321 -0.034040  0.083151  0.255290
# Pclass   -0.335549  1.000000 -0.404114  0.081656  0.016824 -0.548193
# Age      -0.072321 -0.404114  1.000000 -0.250629 -0.179747  0.115477
# SibSp    -0.034040  0.081656 -0.250629  1.000000  0.414542  0.160887
# Parch     0.083151  0.016824 -0.179747  0.414542  1.000000  0.217532
# Fare      0.255290 -0.548193  0.115477  0.160887  0.217532  1.000000

# %%
plt.hexbin(df['Age'],df['Fare'])

# %%
plt.hexbin(df['Age'],df['Fare'],gridsize=10)

# %%
plt.hexbin(df['Age'],df['Fare'],gridsize=10,cmap='coolwarm')

# %%
p=plt.pie(df['Age'])

# %%
p=plt.boxplot(df['Age'])

# %%
p=plt.violinplot(df['Age'])

# %%
plt.figure(figsize=(12,5))
plt.plot(df['Age'].head(25),color=(0.3,0,0.5),marker='o',lw=3,ls='-.',
         markersize=10,markerfacecolor='y',markeredgecolor='g')
plt.plot(df['Fare'].head(25),color=(1,0.4,0.5),marker='s',lw=3,ls='-.',
         markersize=10,markerfacecolor='y',markeredgecolor='g')
#lw=line width, ls=line style
plt.grid()
plt.xlabel('X-axis')
plt.ylabel('Age/Fare')
plt.title('distribution of age and fare')
plt.legend(['Age','Fare'])

plt.ylim([0,100])
plt.xlim([1,25])
plt.xticks(range(1,26,1))
plt.show()

# %%
plt.figure(figsize=(12,10))
plt.subplot(2,1,1)
plt.plot(df['Age'].head(30),color=(0.3,0,0.5),marker='o',lw=3,ls='-.',
         markersize=10,markerfacecolor='y',markeredgecolor='g')

#lw=line width, ls=line style
plt.grid()
plt.xlabel('X-axis')
plt.ylabel('Age (in years)')
plt.title('Age distribution')
plt.legend(['Age','Fare'])

plt.ylim([0,300])
plt.xlim([1,30])
plt.xticks(range(1,31,1))
plt.show()

plt.subplot(2,1,2)
plt.plot(df['Fare'].head(30),color=(1,0.4,0.5),marker='s',lw=3,ls='-.',
         markersize=10,markerfacecolor='y',markeredgecolor='g')
plt.grid()
plt.xlabel('X-axis')
plt.ylabel('Fare')
plt.title('Fare distribution')
plt.legend(['Age'])

plt.ylim([0,300])
plt.xlim([1,25])
plt.xticks(range(1,26,1))
plt.show()
