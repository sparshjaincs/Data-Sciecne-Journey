# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sns

# %%
train  = pd.read_csv("../Datasets/Rainy_Days/train.csv")

# %%
train.head()
# Out:
#        id        Date       Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0  100511  2011-09-25   MountGambier      2.5     16.1       2.4          2.4
# 1  107590  2014-10-19        Woomera     16.4     35.5       0.0         37.6
# 2   43808  2012-06-14     Wollongong     11.4     17.0      10.8          NaN
# 3   62101  2011-08-08           Sale      4.3     12.3       0.2          1.8
# 4   22518  2012-11-30  NorfolkIsland     18.3     23.2       0.0          5.0
#
#    Sunshine WindGustDir  WindGustSpeed  ... Humidity9am Humidity3pm  \
# 0       8.7          SE           37.0  ...        54.0        48.0
# 1       NaN           N           43.0  ...         6.0         1.0
# 2       NaN          NW           28.0  ...        94.0        81.0
# 3       1.2           W           20.0  ...        90.0        74.0
# 4      11.2         ESE           31.0  ...        75.0        71.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
train["Evaporation"] = train.Evaporation.fillna(np.mean(train.Evaporation))

# %%
train.head()
# Out:
#        id        Date       Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0  100511  2011-09-25   MountGambier      2.5     16.1       2.4     2.400000
# 1  107590  2014-10-19        Woomera     16.4     35.5       0.0    37.600000
# 2   43808  2012-06-14     Wollongong     11.4     17.0      10.8     5.473151
# 3   62101  2011-08-08           Sale      4.3     12.3       0.2     1.800000
# 4   22518  2012-11-30  NorfolkIsland     18.3     23.2       0.0     5.000000
#
#    Sunshine WindGustDir  WindGustSpeed  ... Humidity9am Humidity3pm  \
# 0       8.7          SE           37.0  ...        54.0        48.0
# 1       NaN           N           43.0  ...         6.0         1.0
# 2       NaN          NW           28.0  ...        94.0        81.0
# 3       1.2           W           20.0  ...        90.0        74.0
# 4      11.2         ESE           31.0  ...        75.0        71.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...
