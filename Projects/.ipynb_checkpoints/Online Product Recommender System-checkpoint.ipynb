# %%
import requests
import lxml
from bs4 import BeautifulSoup
import pandas as pd

# %% [raw]
# Tasks
# 1. Scrape Products from Amazon, Snapdeal, Flipkart, Ebay, Myntra etc
# 2. Aplly Various Filter Options
# 3. Collect Data and Prepare it from dispaying
# 4. Recommend the related Products w.r.t searched product
# 5. Collect the Search Keywords and show recommended products on homepage
# 6. Scrape detailed products and recommend related products.

# %%
# Amazon
target = "Table"
page=2
url = f"https://www.amazon.in/s?k={target}&page={page}"
HEADERS = ({'User-Agent':
           'Mozilla/5.0 (X11; Linux x86_64)AppleWebKit/537.36 (KHTML, like Gecko)Chrome/44.0.2403.157 Safari/537.36',
                           'Accept-Language': 'en-US, en;q=0.5'})
data = requests.get(url, headers = HEADERS)
data.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(data.content, "lxml")

# %%
db = pd.DataFrame(columns = ["Vendor","Title", "Link", "Image", "Rating","Price", "Actual Price"])
for i in soup.find_all("div", attrs = {"class":"s-asin"}):
    try:
        head = i.find("h2", attrs = {"class" : "s-line-clamp-2"})
        title = head.span.text
        link = "https://www.amazon.in"+head.a.get("href")
        image = i.find("img", attrs = {"class":"s-image"}).get("src")
        price = i.find("span", attrs = {"class": "a-price-whole"}).text
        a_price = i.find("span", attrs= {"class" : "a-offscreen"}).text[1:]
        rating = i.find("span", attrs = {"class":"a-icon-alt"}).text
        temp = pd.DataFrame([["Amazon",title,link,image, price,a_price, rating]], columns=["Vendor","Title","Link","Image","Price","Actual Price","Rating"])
        db = db.append(temp, ignore_index= True)
    except:
        pass

# %%
db
# Out:
#     Vendor                                              Title  \
# 0   Amazon  OET ® Multipurpose Portable Laptop Study Table...
# 1   Amazon  StarAndDaisy 'Bed Buddy' Latop Desk,Portable F...
# 2   Amazon  Ereteken ART Wooden Foldable Adjustable Side T...
# 3   Amazon  Ellics Enterprise Foldable Bed Study Table Por...
# 4   Amazon  White Parrot Foldable Bed Study Table Portable...
# 5   Amazon  STAR WORK MDF Engineered Wood Multipurpose 3 T...
# 6   Amazon  Mumuksha® Smart Multipurpose Foldable Laptop T...
# 7   Amazon  floofy® Smart Standard Multi-Purpose Laptop Ta...
# 8   Amazon  SKY BLUE Smart Multipurpose Foldable Laptop Ta...
# 9   Amazon  JAZON Table Mate Adjustable Foldable Multi - F...
# 10  Amazon  Callas Multipurpose Foldable Laptop Table with...
# 11  Amazon  Tread Mall Laptop Bed Table, Foldable Lap Stan...
# 12  Amazon  Parivar Foldable Bed Study Table Portable Mult...
# 13  Amazon  KATRODIYA Laptop Bed Tray Table, Laptop Desk f...
# 14  Amazon  Ellics Enterprise Presents Foldable Laptop Tab...
# 15  Amazon  NARGO Presents Foldable Laptop Table with Cup ...
# 16  Amazon  Haus Alchemy Laptop Table Wall Mount Foldable ...
# 17  Amazon  InnoFur Trapezi PC/Laptop Desk (Beige) with Ca...
#
#                                                  Link  \
# 0   https://www.amazon.in/gp/slredirect/picassoRed...
# 1   https://www.amazon.in/gp/slredirect/picassoRed...
# 2   https://www.amazon.in/Simran-Handicrafts-Folda...
# 3   https://www.amazon.in/Ellics-Enterprise-Foldab...
# 4   https://www.amazon.in/White-Parrot-Foldable-Po...
# 5   https://www.amazon.in/STAR-WORK-Engineered-Mul...
# 6   https://www.amazon.in/Mumuksha%C2%AE-Multipurp...
# 7   https://www.amazon.in/Standard-Multi-Purpose-F...
# 8   https://www.amazon.in/SKY-BLUE-Multipurpose-Br...
# 9   https://www.amazon.in/gp/slredirect/picassoRed...
# 10  https://www.amazon.in/gp/slredirect/picassoRed...
# 11  https://www.amazon.in/Foldable-Standing-Notebo...
# 12  https://www.amazon.in/Foldable-Portable-Multif...
# 13  https://www.amazon.in/KATRODIYA-Foldable-Noteb...
# 14  https://www.amazon.in/Ellics-Enterprise-Presen...
# 15  https://www.amazon.in/NARGO-Presents-Foldable-...
# 16  https://www.amazon.in/gp/slredirect/picassoRed...
# 17  https://www.amazon.in/gp/slredirect/picassoRed...
#
#                                                 Image              Rating  \
# 0   https://m.media-amazon.com/images/I/817cvrhOTf...  4.0 out of 5 stars
# 1   https://m.media-amazon.com/images/I/616IzXa7uz...  4.4 out of 5 stars
# 2   https://m.media-amazon.com/images/I/61F+QdtgJl...  3.9 out of 5 stars
# 3   https://m.media-amazon.com/images/I/81zgxmLFpy...  4.9 out of 5 stars
# 4   https://m.media-amazon.com/images/I/81I4YIBrGr...  3.6 out of 5 stars
# 5   https://m.media-amazon.com/images/I/81eZzhXg6R...  4.3 out of 5 stars
# 6   https://m.media-amazon.com/images/I/31T3TlDCI7...  3.7 out of 5 stars
# 7   https://m.media-amazon.com/images/I/61OoQ7aE7q...  4.0 out of 5 stars
# 8   https://m.media-amazon.com/images/I/31E8WbHIHl...  1.0 out of 5 stars
# 9   https://m.media-amazon.com/images/I/31Nn6EkV2G...  4.4 out of 5 stars
# 10  https://m.media-amazon.com/images/I/61GQUtqKIp...  4.0 out of 5 stars
# 11  https://m.media-amazon.com/images/I/51ZTlYhF7Y...  3.6 out of 5 stars
# 12  https://m.media-amazon.com/images/I/81cM8k3T7g...  3.6 out of 5 stars
# 13  https://m.media-amazon.com/images/I/81cM8k3T7g...  3.6 out of 5 stars
# 14  https://m.media-amazon.com/images/I/81k6drhPu0...  3.4 out of 5 stars
# 15  https://m.media-amazon.com/images/I/41LmAGCgbx...  1.0 out of 5 stars
# 16  https://m.media-amazon.com/images/I/91baQggCxD...  4.7 out of 5 stars
# 17  https://m.media-amazon.com/images/I/61EE4vG1Jk...  3.6 out of 5 stars
#
#      Price Actual Price
# 0    1,999        1,999
# 1      999          999
# 2      399          399
# 3      494          494
# 4      319          319
# 5   1,006.     1,006.05
# 6      289          289
# 7      499          499
# 8      299          299
# 9    1,378        1,378
# 10     699          699
# 11     449          449
# 12     319          319
# 13     388          388
# 14     483          483
# 15     299          299
# 16   2,299        2,299
# 17   2,799        2,799

# %%
class Product:
    def __init__(self):
        db = pd.DataFrame(columns = ["Vendor","Title", "Link", "Image", "Rating","Price", "Actual Price"])
        status = False
    def set(self,category, page=1):
        target = category
        url = f"https://www.amazon.in/s?k={target}&page={page}"
        HEADERS = ({'User-Agent':
                   'Mozilla/5.0 (X11; Linux x86_64)AppleWebKit/537.36 (KHTML, like Gecko)Chrome/44.0.2403.157 Safari/537.36',
                                   'Accept-Language': 'en-US, en;q=0.5'})
        data = requests.get(url, headers = HEADERS)
        if data.status_code == 200:
            status = True
            soup = BeautifulSoup(data.content, "lxml")
            for i in soup.find_all("div", attrs = {"class":"s-asin"}):
                try:
                    head = i.find("h2", attrs = {"class" : "s-line-clamp-2"})
                    title = head.span.text
                    link = "https://www.amazon.in"+head.a.get("href")
                    image = i.find("img", attrs = {"class":"s-image"}).get("src")
                    price = i.find("span", attrs = {"class": "a-price-whole"}).text
                    a_price = i.find("span", attrs= {"class" : "a-offscreen"}).text[1:]
                    rating = i.find("span", attrs = {"class":"a-icon-alt"}).text
                    temp = pd.DataFrame([["Amazon",title,link,image, price,a_price, rating]], columns=["Vendor","Title","Link","Image","Price","Actual Price","Rating"])
                    self.db = db.append(temp, ignore_index= True)
                except:
                    pass
            
        else:
            status = False 
        return status
    def extract(self, category, page=1):
