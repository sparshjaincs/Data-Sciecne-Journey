# %%
import requests
import lxml
from bs4 import BeautifulSoup
import pandas as pd

# %% [raw]
# Tasks
# 1. Scrape Products from Amazon, Snapdeal, Flipkart, Ebay, Myntra etc
# 2. Aplly Various Filter Options
# 3. Collect Data and Prepare it from dispaying
# 4. Recommend the related Products w.r.t searched product
# 5. Collect the Search Keywords and show recommended products on homepage
# 6. Scrape detailed products and recommend related products.

# %%
# Amazon
target = "Table"
page=3
url = f"https://www.amazon.in/s?k={target}&page={page}"
HEADERS = ({'User-Agent':
           'Mozilla/5.0 (X11; Linux x86_64)AppleWebKit/537.36 (KHTML, like Gecko)Chrome/44.0.2403.157 Safari/537.36',
                           'Accept-Language': 'en-US, en;q=0.5'})
data = requests.get(url, headers = HEADERS)
data.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(data.content, "lxml")

# %%
db = pd.DataFrame(columns = ["Vendor","Title", "Link", "Image", "Rating","Price", "Actual Price"])
for i in soup.find_all("div", attrs = {"class":"s-asin"}):
    try:
        head = i.find("h2", attrs = {"class" : "s-line-clamp-2"})
        title = head.span.text
        link = "https://www.amazon.in"+head.a.get("href")
        image = i.find("img", attrs = {"class":"s-image"}).get("src")
        price = i.find("span", attrs = {"class": "a-price-whole"}).text
        a_price = i.find("span", attrs= {"class" : "a-offscreen"}).text[1:]
        rating = i.find("span", attrs = {"class":"a-icon-alt"}).text
        temp = pd.DataFrame([["Amazon",title,link,image, price,a_price, rating]], columns=["Vendor","Title","Link","Image","Price","Actual Price","Rating"])
        db = db.append(temp, ignore_index= True)
    except:
        pass

# %%
db
# Out:
#    Vendor                                              Title  \
# 0  Amazon  Wipro Re-Chargeable LED Table Lamp, White, Sta...
# 1  Amazon       Esquire Delta Plastic Glossy Trolley (Brown)
# 2  Amazon  WISHGO Smart Multipurpose Foldable Laptop Tabl...
# 3  Amazon  Kuber Industries PVC 6 Seater Transparent Dini...
# 4  Amazon  White Parrot Multi-Purpose Laptop Table - Fold...
# 5  Amazon  YOYOW® Smart Multipurpose Foldable Laptop Tabl...
# 6  Amazon  White Parrot Multi-Purpose Laptop Table - Fold...
# 7  Amazon  Tread Mall Multi-Function Laptop Desk Lap Bed ...
#
#                                                 Link  \
# 0  https://www.amazon.in/Wipro-Re-Chargeable-Tabl...
# 1  https://www.amazon.in/Esquire-Delta-Plastic-Gl...
# 2  https://www.amazon.in/WISHGO-Multipurpose-Fold...
# 3  https://www.amazon.in/Kuber-Industries-Seater-...
# 4  https://www.amazon.in/White-Parrot-Multi-Purpo...
# 5  https://www.amazon.in/Multipurpose-Foldable-Br...
# 6  https://www.amazon.in/White-Parrot-Multi-Purpo...
# 7  https://www.amazon.in/Multi-Function-Laptop-La...
#
#                                                Image              Rating  \
# 0  https://m.media-amazon.com/images/I/71ziqkrREA...  4.3 out of 5 stars
# 1  https://m.media-amazon.com/images/I/81vU+3I3Re...  3.4 out of 5 stars
# 2  https://m.media-amazon.com/images/I/81aCGj+UYl...  3.0 out of 5 stars
# 3  https://m.media-amazon.com/images/I/81RVehC9zF...  4.0 out of 5 stars
# 4  https://m.media-amazon.com/images/I/61RYhY4Mpb...  5.0 out of 5 stars
# 5  https://m.media-amazon.com/images/I/41pOajAUqI...  3.4 out of 5 stars
# 6  https://m.media-amazon.com/images/I/61RYhY4Mpb...  3.1 out of 5 stars
# 7  https://m.media-amazon.com/images/I/51ZTlYhF7Y...  4.0 out of 5 stars
#
#   Price Actual Price
# 0   529          529
# 1   499          499
# 2   289          289
# 3   219          219
# 4   339          339
# 5   299          299
# 6   339          339
# 7   449          449

# %%
def Product(category, page=1):
    url = f"https://www.amazon.in/s?k={category}&page={page}"
    HEADERS = ({'User-Agent':
               'Mozilla/5.0 (X11; Linux x86_64)AppleWebKit/537.36 (KHTML, like Gecko)Chrome/44.0.2403.157 Safari/537.36',
                               'Accept-Language': 'en-US, en;q=0.5'})
    data = requests.get(url, headers = HEADERS)
    soup = BeautifulSoup(data.content, "lxml")
    db = pd.DataFrame(columns = ["Vendor","Title", "Link", "Image", "Rating","Price", "Actual Price"])
    for i in soup.find_all("div", attrs = {"class":"s-asin"}):
        try:
            head = i.find("h2", attrs = {"class" : "s-line-clamp-2"})
            title = head.span.text
            link = "https://www.amazon.in"+head.a.get("href")
            image = i.find("img", attrs = {"class":"s-image"}).get("src")
            price = i.find("span", attrs = {"class": "a-price-whole"}).text
            a_price = i.find("span", attrs= {"class" : "a-offscreen"}).text[1:]
            rating = i.find("span", attrs = {"class":"a-icon-alt"}).text
            temp = pd.DataFrame([["Amazon",title,link,image, price,a_price, rating]], columns=["Vendor","Title","Link","Image","Price","Actual Price","Rating"])
            db = db.append(temp, ignore_index= True)
        except:
            pass
    return db

# %%
# Out:
#     Vendor                                              Title  \
# 0   Amazon        unMIND, A Graphic Guide To Self-realization
# 1   Amazon     Gita & Vedic Wisdom: Greatest Spiritual Wisdom
# 2   Amazon  Sleeping story | English story books for kids:...
# 3   Amazon                                      Bound By Love
# 4   Amazon                     Spoken English Course (Telugu)
# 5   Amazon  Colour With Crayons Book 1 for Kids Age 1 -6 Y...
# 6   Amazon  The Book of Hope: Extraordinary Stories of Ord...
# 7   Amazon  Brijbhoomi Books And Handicrafts® Bhagavad Git...
# 8   Amazon  The Complete Book of Yoga : Karma Yoga, Bhakti...
# 9   Amazon                    The Importance of Being Earnest
# 10  Amazon                           The Elephant in the Womb
# 11  Amazon  Oil & Acrylic: Pet Portraits (How to Draw & Pa...
# 12  Amazon                    Target High 6th Premium Edition
# 13  Amazon  Sex Book for Married Couple: How to Have Ridic...
# 14  Amazon  Motivation- Colouring Book for Adults: Adult C...
# 15  Amazon  RUPA IAS ACADEMY General Studies for UPC, Si ,...
# 16  Amazon  Life's Amazing Secrets: How to Find Balance an...
# 17  Amazon  The Solutions Factory: A Consultant’s Handbook...
# 18  Amazon  How To Win Friends & Influence People, Interna...
#
#                                                  Link  \
# 0   https://www.amazon.in/gp/slredirect/picassoRed...
# 1   https://www.amazon.in/gp/slredirect/picassoRed...
# 2   https://www.amazon.in/Sleeping-story-English-b...
# 3   https://www.amazon.in/Bound-Love-Nityanand-Cha...
# 4   https://www.amazon.in/Spoken-English-Course-Te...
# 5   https://www.amazon.in/Colour-Crayons-Part-Drea...
# 6   https://www.amazon.in/Book-Hope-Extraordinary-...
# 7   https://www.amazon.in/Bhagavad-Gita-Bhaktivend...
# 8   https://www.amazon.in/Complete-Book-Yoga-Karma...
# 9   https://www.amazon.in/gp/slredirect/picassoRed...
# 10  https://www.amazon.in/gp/slredirect/picassoRed...
# 11  https://www.amazon.in/Oil-Acrylic-Portraits-Dr...
# 12  https://www.amazon.in/Target-High-6th-Premium-...
# 13  https://www.amazon.in/Sex-Book-Married-Couple-...
# 14  https://www.amazon.in/Motivation-Adult-Colouri...
# 15  https://www.amazon.in/RUPA-ACADEMY-General-Stu...
# 16  https://www.amazon.in/Lifes-Amazing-Secrets-Ba...
# 17  https://www.amazon.in/gp/slredirect/picassoRed...
# 18  https://www.amazon.in/gp/slredirect/picassoRed...
#
#                                                 Image              Rating  \
# 0   https://m.media-amazon.com/images/I/818L45Nm8c...  4.6 out of 5 stars
# 1   https://m.media-amazon.com/images/I/81NhSeATsN...  4.1 out of 5 stars
# 2   https://m.media-amazon.com/images/I/71aN5GoC+K...  1.0 out of 5 stars
# 3   https://m.media-amazon.com/images/I/81LNCRqeDP...  5.0 out of 5 stars
# 4   https://m.media-amazon.com/images/I/71CWkVIhrK...  4.3 out of 5 stars
# 5   https://m.media-amazon.com/images/I/81GEhSSrjK...  4.2 out of 5 stars
# 6   https://m.media-amazon.com/images/I/810D3k9n+o...  5.0 out of 5 stars
# 7   https://m.media-amazon.com/images/I/310ILDQr5l...  4.7 out of 5 stars
# 8   https://m.media-amazon.com/images/I/712qS6BINt...  4.6 out of 5 stars
# 9   https://m.media-amazon.com/images/I/71RZBszBLk...  4.5 out of 5 stars
# 10  https://m.media-amazon.com/images/I/512HsnURFZ...  5.0 out of 5 stars
# 11  https://m.media-amazon.com/images/I/91z5MwX60-...  4.2 out of 5 stars
# 12  https://m.media-amazon.com/images/I/91z0JhL6Rw...  4.3 out of 5 stars
# 13  https://m.media-amazon.com/images/I/61G2OFBdu1...  5.0 out of 5 stars
# 14  https://m.media-amazon.com/images/I/81dSCP8Hx7...  4.5 out of 5 stars
# 15  https://m.media-amazon.com/images/I/71Y5V6U7ap...  4.1 out of 5 stars
# 16  https://m.media-amazon.com/images/I/81N7FmJhbh...  4.6 out of 5 stars
# 17  https://m.media-amazon.com/images/I/51WhYAKsVs...  4.4 out of 5 stars
# 18  https://m.media-amazon.com/images/I/71wrQ0bR8+...  4.5 out of 5 stars
#
#     Price Actual Price
# 0     249          249
# 1     149          149
# 2       0            0
# 3     199          199
# 4     349          349
# 5      45           45
# 6     269          269
# 7     185          185
# 8     132          132
# 9      89           89
# 10   319.       319.20
# 11    500          500
# 12  1,179        1,179
# 13      0            0
# 14     99           99
# 15    699          699
# 16    161          161
# 17    381          381
# 18    140          140
